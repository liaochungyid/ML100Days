# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %% [markdown]
# # [作業目標]
# - 仿造範例的MAE函數, 自己寫一個MSE函數(參考上面公式)

# %% [markdown]
# # [作業重點]
# - 注意程式的縮排
# - 是否能將數學公式, 轉換為 Python 的函式組合? (In[2], Out[2])

# %%
# 載入基礎套件與代稱
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# 定義 mean_squared_error 這個函數, 計算並傳回 MSE
def mean_squared_error(y, yp):
    mse = sum(np.power(y - yp,2)) / len(y)
    return mse

# %%
# 與範例相同, 不另外解說
w = 3
b = 0.5
x_lin = np.linspace(0, 100, 101)
y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
# 與範例相同, 不另外解說
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 306.366
# The Mean absolute error is 13.454

# %% [markdown]
# # [作業2]
#
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
#
# 1. 你選的這組資料為何重要
# 找到的資料是"世界幸福報告"(World Happiness Report)，由聯合國"永續發展方法網路"(Sustainable Development Solutions Network)收集提供；其重要性為可能可以用該國家(地區)的平均壽命、貪腐程度、平均收入、自由程度、人民慷慨程度、以及家庭狀況等六項，尋找出使人們感到幸福的原因；其中有欄表格是"反烏托邦殘差"(Dystopia Residual)，是快樂指數(0-10分) 扣除 上述六個分數加總 的差值，這差值代表的意義深遠，以統一表準來說，全世界的"反烏托邦差值"應該相同(意思是當所有人在上述六項指標都達到最差水平時，或說處於"反烏托邦"狀態，感受到的幸福程度應該都一樣"差")，但是明顯調查結果與理論不同；
# 我所選這組資料並非可以完整探討人類感到幸福的原因，雖可大致分析原因，但存在不同國情的"幸福認知差異"，是一組可以探討造成人類幸福的指標缺乏哪些部分，或是須將資料依照"反烏托邦殘差"(Dystopia Residual)的差異給予六個指標權重。
#
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
# 資料由蓋洛普世界調查(Gallup World Poll)所提供，問答形式以坎特里爾階梯（Cantril ladder）量表作為答題計分，調查方式分為隨機電話調查、直接訪談等兩種，美國、加拿大、西歐、日本、澳洲等地依該地人口分布使用隨機電話調查，發展中國家使用面對面訪談；隨機電話調查約使用30分鐘，直接訪談約耗時一小時；對象為15歲以上男女，其盡可能涵蓋該地區所有地方人口，包含落後偏鄉，除了部分有可能危害調查人員安全或當地人感到威脅情況，才不會被訪談。
# 大部分採樣對象至少1000人，人口較多國家，例如俄羅斯、中國等，採樣至少2000人，僅極少部分地方採樣介於500至1000人。
#
# 3. 蒐集而來的資料型態為何
# 資料收集後蓋洛普世界調查(Gallup World Poll)對資料執行權重，例如使用電話訪談，但被訪談者使用市內電話與手機，雖當下處不同地區(或手機登記地點不同)但調查中發現其屬另一個地區，在檢視所有被訪談人後，將依照被調查人地點做權重調整；同時也移除無回答、明顯亂回答與問題過於贅述，導致被訪談人難以理解或不想回答的部分。
# 本組資料除國家(地區)以及所屬地理區塊(例如拉丁美洲)，其他皆以數值(0-10)的方式呈現，無須轉換資料型態，或是虛擬變量 (Dummy variable)。
#
# 4. 這組資料想解決的問題如何評估
# 資料組想解決的問題是"是甚麼造成人們感到幸福"，如第一項題目所提，"反烏托邦殘差"(Dystopia Residual)有著明顯的偏差，需先找到消彌或減少"幸福認知差異"會使結果更具代表性；本組資料並非要"預測"幸福指數，而是使用前述的"幸福認知差異"所必須的六項指標權重，依權種大小可能可以推估人類對幸福感醒響較大的指標是哪一項。
#
#
# # [作業3]
#
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
# 提升業績：單位時間內收益(營收扣除固定與移動成本)提升
# 為提升載客性價比，司機的空檔時間要縮短(意旨錢一位客人下車後，短時間就有客人上車)；司機空檔距離要縮短(意旨前一位客人與後一位客人相聚不宜太遠)；司機所移動單位距離的時間要縮短(意旨避開紅綠燈多，或車多塞車的地方)
#
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
# 所需資料：乘客上下車位置，載客路線，前往載客前路線，平均移動速度，低平均移動速度位置段，經常車多之路線及時段
# 蒐集方法：使用乘車APP(例如UBER)收集乘車與車隊資料，向大型地圖供應商(例如GOOGLE、GARMIN)找尋路線流量資料，同時向地方主管機關(例如台北市交通局)索取多事故、車潮紀錄資料。
#
# 3. 蒐集而來的資料型態為何
# 連續時間座標、時間、位置、流量、乘客資訊(上下車地點、移動路段速度、費用等)、空車資訊等
#
#
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
# 初次資料：未避開塞車資料、長司機空檔時間地區、長司機空檔距離地區，與避開塞車資料、短司機空檔時間地區、短司機空檔距離地區對比參照；提供消費者、司機於乘車APP選擇(乘客：是否避開車潮，可所短時間但增加路程及車資)(司機：是否避開多空檔地段，可能減少乘客人次數，但減少空檔時間與移動距離)
# 二次資料可提供更完整資訊，重新訓練模型
